# %% [markdown]
# # 課題1：住宅価格のデータの前処理
#
# ここではデータの前処理について理解いただくための課題を用意しました。
#
# ここでは住宅価格のデータセットを利用します。今回の住宅価格のデータは、Colabのランタイムに標準でインストールされている「カリフォルニア州の住宅価格」ではなく、以下のページで配布されている「アイオワ州の住宅価格」のデータを利用します。
#
# このデータは、Dean De Cockという統計学者の論文が出典元とされていて、以下のサイトでCSVファイルの配布と各列の説明がされています。
#
# [Housing prices in Ames, Iowa](https://www.openintro.org/data/index.php?data=ames)
#
# 各セルに入っているコメントの下に、実行するコードを記入してください。また、作業内容の一部にPandasの公式ドキュメントへのリンクを追記していますので、わからない部分がありましたら参照してください。
#
# **注意点：**
#
# - 列名にドット（`.`）が入っているとPandasの処理中にエラーが発生するため、元データの列名から `.` を削除しています
# - PID列のみ、元データから削除しています

# %% [markdown]
# ## 1. 必要なライブラリの読み込み

# %%
# 必要なライブラリの読み込み（変更しないでください）
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# ## 2. データの読み込み
#
# CSVファイル *iowa_ames_housing_price.csv* を読み込み、内容を確認します。

# %%
pd.options.display.max_columns = None

# %%
# データを変数datasetに読み込む
dataset = pd.read_csv("./iowa_ames_housing_price.csv")

# %%
# データの最初の5行を表示
dataset.head()
# Out:
#    Order  area   price  MSSubClass MSZoning  LotFrontage  LotArea Street  \
# 0      1  1710  208500          60       RL         65.0     8450   Pave
# 1      2  1262  181500          20       RL         80.0     9600   Pave
# 2      3  1786  223500          60       RL         68.0    11250   Pave
# 3      4  1717  140000          70       RL         60.0     9550   Pave
# 4      5  2198  250000          60       RL         84.0    14260   Pave
#
#   Alley LotShape LandContour Utilities LotConfig LandSlope Neighborhood  \
# 0   NaN      Reg         Lvl    AllPub    Inside       Gtl      CollgCr
# 1   NaN      Reg         Lvl    AllPub       FR2       Gtl      Veenker
# 2   NaN      IR1         Lvl    AllPub    Inside       Gtl      CollgCr
# 3   NaN      IR1         Lvl    AllPub    Corner       Gtl      Crawfor
# 4   NaN      IR1         Lvl    AllPub       FR2       Gtl      NoRidge
#
#   Condition1 Condition2 BldgType HouseStyle  OverallQual  OverallCond  \
# 0       Norm       Norm     1Fam     2Story            7            5
# 1      Feedr       Norm     1Fam     1Story            6            8
# 2       Norm       Norm     1Fam     2Story            7            5
# 3       Norm       Norm     1Fam     2Story            7            5
# 4       Norm       Norm     1Fam     2Story            8            5
#
#    YearBuilt  YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd  \
# 0       2003          2003     Gable  CompShg     VinylSd     VinylSd
# 1       1976          1976     Gable  CompShg     MetalSd     MetalSd
# 2       2001          2002     Gable  CompShg     VinylSd     VinylSd
# 3       1915          1970     Gable  CompShg     Wd Sdng     Wd Shng
# 4       2000          2000     Gable  CompShg     VinylSd     VinylSd
#
#   MasVnrType  MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond  \
# 0    BrkFace       196.0        Gd        TA      PConc       Gd       TA
# 1        NaN         0.0        TA        TA     CBlock       Gd       TA
# 2    BrkFace       162.0        Gd        TA      PConc       Gd       TA
# 3        NaN         0.0        TA        TA     BrkTil       TA       Gd
# 4    BrkFace       350.0        Gd        TA      PConc       Gd       TA
#
#   BsmtExposure BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  BsmtUnfSF  \
# 0           No          GLQ         706          Unf           0        150
# 1           Gd          ALQ         978          Unf           0        284
# 2           Mn          GLQ         486          Unf           0        434
# 3           No          ALQ         216          Unf           0        540
# 4           Av          GLQ         655          Unf           0        490
#
#    TotalBsmtSF Heating HeatingQC CentralAir Electrical  X1stFlrSF  X2ndFlrSF  \
# 0          856    GasA        Ex          Y      SBrkr        856        854
# 1         1262    GasA        Ex          Y      SBrkr       1262          0
# 2          920    GasA        Ex          Y      SBrkr        920        866
# 3          756    GasA        Gd          Y      SBrkr        961        756
# 4         1145    GasA        Ex          Y      SBrkr       1145       1053
#
#    LowQualFinSF  BsmtFullBath  BsmtHalfBath  FullBath  HalfBath  BedroomAbvGr  \
# 0             0             1             0         2         1             3
# 1             0             0             1         2         0             3
# 2             0             1             0         2         1             3
# 3             0             1             0         1         0             3
# 4             0             1             0         2         1             4
#
#    KitchenAbvGr KitchenQual  TotRmsAbvGrd Functional  Fireplaces FireplaceQu  \
# 0             1          Gd             8        Typ           0         NaN
# 1             1          TA             6        Typ           1          TA
# 2             1          Gd             6        Typ           1          TA
# 3             1          Gd             7        Typ           1          Gd
# 4             1          Gd             9        Typ           1          TA
#
#   GarageType  GarageYrBlt GarageFinish  GarageCars  GarageArea GarageQual  \
# 0     Attchd       2003.0          RFn           2         548         TA
# 1     Attchd       1976.0          RFn           2         460         TA
# 2     Attchd       2001.0          RFn           2         608         TA
# 3     Detchd       1998.0          Unf           3         642         TA
# 4     Attchd       2000.0          RFn           3         836         TA
#
#   GarageCond PavedDrive  WoodDeckSF  OpenPorchSF  EnclosedPorch  X3SsnPorch  \
# 0         TA          Y           0           61              0           0
# 1         TA          Y         298            0              0           0
# 2         TA          Y           0           42              0           0
# 3         TA          Y           0           35            272           0
# 4         TA          Y         192           84              0           0
#
#    ScreenPorch  PoolArea PoolQC Fence MiscFeature  MiscVal  MoSold  YrSold  \
# 0            0         0    NaN   NaN         NaN        0       2    2008
# 1            0         0    NaN   NaN         NaN        0       5    2007
# 2            0         0    NaN   NaN         NaN        0       9    2008
# 3            0         0    NaN   NaN         NaN        0       2    2006
# 4            0         0    NaN   NaN         NaN        0      12    2008
#
#   SaleType SaleCondition
# 0       WD        Normal
# 1       WD        Normal
# 2       WD        Normal
# 3       WD       Abnorml
# 4       WD        Normal

# %% [markdown]
# 全データの行数と列数を取得します。DataFrameの`shape` プロパティを参照します。
#
# 参照：https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.shape.html

# %%
# データの行数、列数を表示
dataset.shape
# Out:
# (1460, 81)

# %%
# 形状を確認
print(f"データの形状: {dataset.shape}")
print(f"行数: {dataset.shape[0]}")
print(f"列数: {dataset.shape[1]}")
# Out:
# データの形状: (1460, 81)
# 行数: 1460
# 列数: 81

# %% [markdown]
# ## 3. 要約統計量を出力する
#
# データ数、平均や中央値、標準偏差などの統計量を確認することで、データへの理解を深めます。
#
# DataFrameの `describe()` を使うことで、様々な統計量の情報を要約として表示されます。
#
# 参考：https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.describe.html

# %%
# 要約統計量を表示
dataset.describe()
# Out:
#              Order         area          price   MSSubClass  LotFrontage  \
# count  1460.000000  1460.000000    1460.000000  1460.000000  1201.000000
# mean    730.500000  1515.463699  180921.195890    56.897260    70.049958
# std     421.610009   525.480383   79442.502883    42.300571    24.284752
# min       1.000000   334.000000   34900.000000    20.000000    21.000000
# 25%     365.750000  1129.500000  129975.000000    20.000000    59.000000
# 50%     730.500000  1464.000000  163000.000000    50.000000    69.000000
# 75%    1095.250000  1776.750000  214000.000000    70.000000    80.000000
# max    1460.000000  5642.000000  755000.000000   190.000000   313.000000
#
#              LotArea  OverallQual  OverallCond    YearBuilt  YearRemodAdd  \
# count    1460.000000  1460.000000  1460.000000  1460.000000   1460.000000
# mean    10516.828082     6.099315     5.575342  1971.267808   1984.865753
# std      9981.264932     1.382997     1.112799    30.202904     20.645407
# min      1300.000000     1.000000     1.000000  1872.000000   1950.000000
# 25%      7553.500000     5.000000     5.000000  1954.000000   1967.000000
# 50%      9478.500000     6.000000     5.000000  1973.000000   1994.000000
# 75%     11601.500000     7.000000     6.000000  2000.000000   2004.000000
# max    215245.000000    10.000000     9.000000  2010.000000   2010.000000
#
#         MasVnrArea   BsmtFinSF1   BsmtFinSF2    BsmtUnfSF  TotalBsmtSF  \
# count  1452.000000  1460.000000  1460.000000  1460.000000  1460.000000
# mean    103.685262   443.639726    46.549315   567.240411  1057.429452
# std     181.066207   456.098091   161.319273   441.866955   438.705324
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.000000     0.000000     0.000000   223.000000   795.750000
# 50%       0.000000   383.500000     0.000000   477.500000   991.500000
# 75%     166.000000   712.250000     0.000000   808.000000  1298.250000
# max    1600.000000  5644.000000  1474.000000  2336.000000  6110.000000
#
#          X1stFlrSF    X2ndFlrSF  LowQualFinSF  BsmtFullBath  BsmtHalfBath  \
# count  1460.000000  1460.000000   1460.000000   1460.000000   1460.000000
# mean   1162.626712   346.992466      5.844521      0.425342      0.057534
# std     386.587738   436.528436     48.623081      0.518911      0.238753
# min     334.000000     0.000000      0.000000      0.000000      0.000000
# 25%     882.000000     0.000000      0.000000      0.000000      0.000000
# 50%    1087.000000     0.000000      0.000000      0.000000      0.000000
# 75%    1391.250000   728.000000      0.000000      1.000000      0.000000
# max    4692.000000  2065.000000    572.000000      3.000000      2.000000
#
#           FullBath     HalfBath  BedroomAbvGr  KitchenAbvGr  TotRmsAbvGrd  \
# count  1460.000000  1460.000000   1460.000000   1460.000000   1460.000000
# mean      1.565068     0.382877      2.866438      1.046575      6.517808
# std       0.550916     0.502885      0.815778      0.220338      1.625393
# min       0.000000     0.000000      0.000000      0.000000      2.000000
# 25%       1.000000     0.000000      2.000000      1.000000      5.000000
# 50%       2.000000     0.000000      3.000000      1.000000      6.000000
# 75%       2.000000     1.000000      3.000000      1.000000      7.000000
# max       3.000000     2.000000      8.000000      3.000000     14.000000
#
#         Fireplaces  GarageYrBlt   GarageCars   GarageArea   WoodDeckSF  \
# count  1460.000000  1379.000000  1460.000000  1460.000000  1460.000000
# mean      0.613014  1978.506164     1.767123   472.980137    94.244521
# std       0.644666    24.689725     0.747315   213.804841   125.338794
# min       0.000000  1900.000000     0.000000     0.000000     0.000000
# 25%       0.000000  1961.000000     1.000000   334.500000     0.000000
# 50%       1.000000  1980.000000     2.000000   480.000000     0.000000
# 75%       1.000000  2002.000000     2.000000   576.000000   168.000000
# max       3.000000  2010.000000     4.000000  1418.000000   857.000000
#
#        OpenPorchSF  EnclosedPorch   X3SsnPorch  ScreenPorch     PoolArea  \
# count  1460.000000    1460.000000  1460.000000  1460.000000  1460.000000
# mean     46.660274      21.954110     3.409589    15.060959     2.758904
# std      66.256028      61.119149    29.317331    55.757415    40.177307
# min       0.000000       0.000000     0.000000     0.000000     0.000000
# 25%       0.000000       0.000000     0.000000     0.000000     0.000000
# 50%      25.000000       0.000000     0.000000     0.000000     0.000000
# 75%      68.000000       0.000000     0.000000     0.000000     0.000000
# max     547.000000     552.000000   508.000000   480.000000   738.000000
#
#             MiscVal       MoSold       YrSold
# count   1460.000000  1460.000000  1460.000000
# mean      43.489041     6.321918  2007.815753
# std      496.123024     2.703626     1.328095
# min        0.000000     1.000000  2006.000000
# 25%        0.000000     5.000000  2007.000000
# 50%        0.000000     6.000000  2008.000000
# 75%        0.000000     8.000000  2009.000000
# max    15500.000000    12.000000  2010.000000

# %% [markdown]
# ## 4. 基本的なデータの操作

# %% [markdown]
# データの抽出・列の分割について学びます。

# %% [markdown]
# ### インデックスを用いた行の指定

# %%
# インデックス番号0から10行分抽出
dataset.iloc[:10]
# Out:
#    Order  area   price  MSSubClass MSZoning  LotFrontage  LotArea Street  \
# 0      1  1710  208500          60       RL         65.0     8450   Pave
# 1      2  1262  181500          20       RL         80.0     9600   Pave
# 2      3  1786  223500          60       RL         68.0    11250   Pave
# 3      4  1717  140000          70       RL         60.0     9550   Pave
# 4      5  2198  250000          60       RL         84.0    14260   Pave
# 5      6  1362  143000          50       RL         85.0    14115   Pave
# 6      7  1694  307000          20       RL         75.0    10084   Pave
# 7      8  2090  200000          60       RL          NaN    10382   Pave
# 8      9  1774  129900          50       RM         51.0     6120   Pave
# 9     10  1077  118000         190       RL         50.0     7420   Pave
#
#   Alley LotShape LandContour Utilities LotConfig LandSlope Neighborhood  \
# 0   NaN      Reg         Lvl    AllPub    Inside       Gtl      CollgCr
# 1   NaN      Reg         Lvl    AllPub       FR2       Gtl      Veenker
# 2   NaN      IR1         Lvl    AllPub    Inside       Gtl      CollgCr
# 3   NaN      IR1         Lvl    AllPub    Corner       Gtl      Crawfor
# 4   NaN      IR1         Lvl    AllPub       FR2       Gtl      NoRidge
# 5   NaN      IR1         Lvl    AllPub    Inside       Gtl      Mitchel
# 6   NaN      Reg         Lvl    AllPub    Inside       Gtl      Somerst
# 7   NaN      IR1         Lvl    AllPub    Corner       Gtl       NWAmes
# 8   NaN      Reg         Lvl    AllPub    Inside       Gtl      OldTown
# 9   NaN      Reg         Lvl    AllPub    Corner       Gtl      BrkSide
#
#   Condition1 Condition2 BldgType HouseStyle  OverallQual  OverallCond  \
# 0       Norm       Norm     1Fam     2Story            7            5
# 1      Feedr       Norm     1Fam     1Story            6            8
# 2       Norm       Norm     1Fam     2Story            7            5
# 3       Norm       Norm     1Fam     2Story            7            5
# 4       Norm       Norm     1Fam     2Story            8            5
# 5       Norm       Norm     1Fam     1.5Fin            5            5
# 6       Norm       Norm     1Fam     1Story            8            5
# 7       PosN       Norm     1Fam     2Story            7            6
# 8     Artery       Norm     1Fam     1.5Fin            7            5
# 9     Artery     Artery   2fmCon     1.5Unf            5            6
#
#    YearBuilt  YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd  \
# 0       2003          2003     Gable  CompShg     VinylSd     VinylSd
# 1       1976          1976     Gable  CompShg     MetalSd     MetalSd
# 2       2001          2002     Gable  CompShg     VinylSd     VinylSd
# 3       1915          1970     Gable  CompShg     Wd Sdng     Wd Shng
# 4       2000          2000     Gable  CompShg     VinylSd     VinylSd
# 5       1993          1995     Gable  CompShg     VinylSd     VinylSd
# 6       2004          2005     Gable  CompShg     VinylSd     VinylSd
# 7       1973          1973     Gable  CompShg     HdBoard     HdBoard
# 8       1931          1950     Gable  CompShg     BrkFace     Wd Shng
# 9       1939          1950     Gable  CompShg     MetalSd     MetalSd
#
#   MasVnrType  MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond  \
# 0    BrkFace       196.0        Gd        TA      PConc       Gd       TA
# 1        NaN         0.0        TA        TA     CBlock       Gd       TA
# 2    BrkFace       162.0        Gd        TA      PConc       Gd       TA
# 3        NaN         0.0        TA        TA     BrkTil       TA       Gd
# 4    BrkFace       350.0        Gd        TA      PConc       Gd       TA
# 5        NaN         0.0        TA        TA       Wood       Gd       TA
# 6      Stone       186.0        Gd        TA      PConc       Ex       TA
# 7      Stone       240.0        TA        TA     CBlock       Gd       TA
# 8        NaN         0.0        TA        TA     BrkTil       TA       TA
# 9        NaN         0.0        TA        TA     BrkTil       TA       TA
#
#   BsmtExposure BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  BsmtUnfSF  \
# 0           No          GLQ         706          Unf           0        150
# 1           Gd          ALQ         978          Unf           0        284
# 2           Mn          GLQ         486          Unf           0        434
# 3           No          ALQ         216          Unf           0        540
# 4           Av          GLQ         655          Unf           0        490
# 5           No          GLQ         732          Unf           0         64
# 6           Av          GLQ        1369          Unf           0        317
# 7           Mn          ALQ         859          BLQ          32        216
# 8           No          Unf           0          Unf           0        952
# 9           No          GLQ         851          Unf           0        140
#
#    TotalBsmtSF Heating HeatingQC CentralAir Electrical  X1stFlrSF  X2ndFlrSF  \
# 0          856    GasA        Ex          Y      SBrkr        856        854
# 1         1262    GasA        Ex          Y      SBrkr       1262          0
# 2          920    GasA        Ex          Y      SBrkr        920        866
# 3          756    GasA        Gd          Y      SBrkr        961        756
# 4         1145    GasA        Ex          Y      SBrkr       1145       1053
# 5          796    GasA        Ex          Y      SBrkr        796        566
# 6         1686    GasA        Ex          Y      SBrkr       1694          0
# 7         1107    GasA        Ex          Y      SBrkr       1107        983
# 8          952    GasA        Gd          Y      FuseF       1022        752
# 9          991    GasA        Ex          Y      SBrkr       1077          0
#
#    LowQualFinSF  BsmtFullBath  BsmtHalfBath  FullBath  HalfBath  BedroomAbvGr  \
# 0             0             1             0         2         1             3
# 1             0             0             1         2         0             3
# 2             0             1             0         2         1             3
# 3             0             1             0         1         0             3
# 4             0             1             0         2         1             4
# 5             0             1             0         1         1             1
# 6             0             1             0         2         0             3
# 7             0             1             0         2         1             3
# 8             0             0             0         2         0             2
# 9             0             1             0         1         0             2
#
#    KitchenAbvGr KitchenQual  TotRmsAbvGrd Functional  Fireplaces FireplaceQu  \
# 0             1          Gd             8        Typ           0         NaN
# 1             1          TA             6        Typ           1          TA
# 2             1          Gd             6        Typ           1          TA
# 3             1          Gd             7        Typ           1          Gd
# 4             1          Gd             9        Typ           1          TA
# 5             1          TA             5        Typ           0         NaN
# 6             1          Gd             7        Typ           1          Gd
# 7             1          TA             7        Typ           2          TA
# 8             2          TA             8       Min1           2          TA
# 9             2          TA             5        Typ           2          TA
#
#   GarageType  GarageYrBlt GarageFinish  GarageCars  GarageArea GarageQual  \
# 0     Attchd       2003.0          RFn           2         548         TA
# 1     Attchd       1976.0          RFn           2         460         TA
# 2     Attchd       2001.0          RFn           2         608         TA
# 3     Detchd       1998.0          Unf           3         642         TA
# 4     Attchd       2000.0          RFn           3         836         TA
# 5     Attchd       1993.0          Unf           2         480         TA
# 6     Attchd       2004.0          RFn           2         636         TA
# 7     Attchd       1973.0          RFn           2         484         TA
# 8     Detchd       1931.0          Unf           2         468         Fa
# 9     Attchd       1939.0          RFn           1         205         Gd
#
#   GarageCond PavedDrive  WoodDeckSF  OpenPorchSF  EnclosedPorch  X3SsnPorch  \
# 0         TA          Y           0           61              0           0
# 1         TA          Y         298            0              0           0
# 2         TA          Y           0           42              0           0
# 3         TA          Y           0           35            272           0
# 4         TA          Y         192           84              0           0
# 5         TA          Y          40           30              0         320
# 6         TA          Y         255           57              0           0
# 7         TA          Y         235          204            228           0
# 8         TA          Y          90            0            205           0
# 9         TA          Y           0            4              0           0
#
#    ScreenPorch  PoolArea PoolQC  Fence MiscFeature  MiscVal  MoSold  YrSold  \
# 0            0         0    NaN    NaN         NaN        0       2    2008
# 1            0         0    NaN    NaN         NaN        0       5    2007
# 2            0         0    NaN    NaN         NaN        0       9    2008
# 3            0         0    NaN    NaN         NaN        0       2    2006
# 4            0         0    NaN    NaN         NaN        0      12    2008
# 5            0         0    NaN  MnPrv        Shed      700      10    2009
# 6            0         0    NaN    NaN         NaN        0       8    2007
# 7            0         0    NaN    NaN        Shed      350      11    2009
# 8            0         0    NaN    NaN         NaN        0       4    2008
# 9            0         0    NaN    NaN         NaN        0       1    2008
#
#   SaleType SaleCondition
# 0       WD        Normal
# 1       WD        Normal
# 2       WD        Normal
# 3       WD       Abnorml
# 4       WD        Normal
# 5       WD        Normal
# 6       WD        Normal
# 7       WD        Normal
# 8       WD       Abnorml
# 9       WD        Normal

# %%
# 最初の10行だけ抽出し、「price」と「LotArea」の列を表示
dataset[['price', 'LotArea']][:10]
# Out:
#     price  LotArea
# 0  208500     8450
# 1  181500     9600
# 2  223500    11250
# 3  140000     9550
# 4  250000    14260
# 5  143000    14115
# 6  307000    10084
# 7  200000    10382
# 8  129900     6120
# 9  118000     7420

# %% [markdown]
# ### カラム間の演算
#
# PandasのDataFrameでは、列同士の四則演算、ならびに新しい列の追加ができます。
#
# たとえば、`df` というDataFrameの変数があり、中に `a`,`b` というカラムが存在するとき、`df['c'] = df['a'] + df['b']` と記述することで、`a`列と`b`列の加算結果を `c` という新しい列として `df` に追加してくれます。

# %%
# 「X1stFlrSF」と「X2ndFlrSF」を合計した「XFlrSF_total」を新たな列としてdatasetに加える
dataset['XFlrSF_total'] = dataset['X1stFlrSF'] + dataset['X2ndFlrSF']

# %%
# datasetからloc関数を使用して「X1stFlrSF」と「X2ndFlrSF」、「XFlrSF_total」を先頭から5行分表示し、正しく追加されていることを確認する
dataset[['X1stFlrSF', 'X2ndFlrSF', 'XFlrSF_total']][:5]
# Out:
#    X1stFlrSF  X2ndFlrSF  XFlrSF_total
# 0        856        854          1710
# 1       1262          0          1262
# 2        920        866          1786
# 3        961        756          1717
# 4       1145       1053          2198

# %% [markdown]
#  ### ダミー変数の作成
#
# 列 `SaleType` は `WD`, `New`, `COD` などで構成されたカテゴリーデータです。 `get_dummies()` 関数を使用してダミー変数に変換しましょう。
#
# 参考：https://pandas.pydata.org/docs/reference/api/pandas.get_dummies.html

# %%
# 列'SaleType'をダミー変数に展開したものを変数 dataset に上書きします
dataset3 = pd.get_dummies(data=dataset, columns=['SaleType'])

# %%
# ダミー変数が作成されていることを確認します　(datasetの最初の5行だけ出力)
dataset3.head()
# Out:
#    Order  area   price  MSSubClass MSZoning  LotFrontage  LotArea Street  \
# 0      1  1710  208500          60       RL         65.0     8450   Pave
# 1      2  1262  181500          20       RL         80.0     9600   Pave
# 2      3  1786  223500          60       RL         68.0    11250   Pave
# 3      4  1717  140000          70       RL         60.0     9550   Pave
# 4      5  2198  250000          60       RL         84.0    14260   Pave
#
#   Alley LotShape LandContour Utilities LotConfig LandSlope Neighborhood  \
# 0   NaN      Reg         Lvl    AllPub    Inside       Gtl      CollgCr
# 1   NaN      Reg         Lvl    AllPub       FR2       Gtl      Veenker
# 2   NaN      IR1         Lvl    AllPub    Inside       Gtl      CollgCr
# 3   NaN      IR1         Lvl    AllPub    Corner       Gtl      Crawfor
# 4   NaN      IR1         Lvl    AllPub       FR2       Gtl      NoRidge
#
#   Condition1 Condition2 BldgType HouseStyle  OverallQual  OverallCond  \
# 0       Norm       Norm     1Fam     2Story            7            5
# 1      Feedr       Norm     1Fam     1Story            6            8
# 2       Norm       Norm     1Fam     2Story            7            5
# 3       Norm       Norm     1Fam     2Story            7            5
# 4       Norm       Norm     1Fam     2Story            8            5
#
#    YearBuilt  YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd  \
# 0       2003          2003     Gable  CompShg     VinylSd     VinylSd
# 1       1976          1976     Gable  CompShg     MetalSd     MetalSd
# 2       2001          2002     Gable  CompShg     VinylSd     VinylSd
# 3       1915          1970     Gable  CompShg     Wd Sdng     Wd Shng
# 4       2000          2000     Gable  CompShg     VinylSd     VinylSd
#
#   MasVnrType  MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond  \
# 0    BrkFace       196.0        Gd        TA      PConc       Gd       TA
# 1        NaN         0.0        TA        TA     CBlock       Gd       TA
# 2    BrkFace       162.0        Gd        TA      PConc       Gd       TA
# 3        NaN         0.0        TA        TA     BrkTil       TA       Gd
# 4    BrkFace       350.0        Gd        TA      PConc       Gd       TA
#
#   BsmtExposure BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  BsmtUnfSF  \
# 0           No          GLQ         706          Unf           0        150
# 1           Gd          ALQ         978          Unf           0        284
# 2           Mn          GLQ         486          Unf           0        434
# 3           No          ALQ         216          Unf           0        540
# 4           Av          GLQ         655          Unf           0        490
#
#    TotalBsmtSF Heating HeatingQC CentralAir Electrical  X1stFlrSF  X2ndFlrSF  \
# 0          856    GasA        Ex          Y      SBrkr        856        854
# 1         1262    GasA        Ex          Y      SBrkr       1262          0
# 2          920    GasA        Ex          Y      SBrkr        920        866
# 3          756    GasA        Gd          Y      SBrkr        961        756
# 4         1145    GasA        Ex          Y      SBrkr       1145       1053
#
#    LowQualFinSF  BsmtFullBath  BsmtHalfBath  FullBath  HalfBath  BedroomAbvGr  \
# 0             0             1             0         2         1             3
# 1             0             0             1         2         0             3
# 2             0             1             0         2         1             3
# 3             0             1             0         1         0             3
# 4             0             1             0         2         1             4
#
#    KitchenAbvGr KitchenQual  TotRmsAbvGrd Functional  Fireplaces FireplaceQu  \
# 0             1          Gd             8        Typ           0         NaN
# 1             1          TA             6        Typ           1          TA
# 2             1          Gd             6        Typ           1          TA
# 3             1          Gd             7        Typ           1          Gd
# 4             1          Gd             9        Typ           1          TA
#
#   GarageType  GarageYrBlt GarageFinish  GarageCars  GarageArea GarageQual  \
# 0     Attchd       2003.0          RFn           2         548         TA
# 1     Attchd       1976.0          RFn           2         460         TA
# 2     Attchd       2001.0          RFn           2         608         TA
# 3     Detchd       1998.0          Unf           3         642         TA
# 4     Attchd       2000.0          RFn           3         836         TA
#
#   GarageCond PavedDrive  WoodDeckSF  OpenPorchSF  EnclosedPorch  X3SsnPorch  \
# 0         TA          Y           0           61              0           0
# 1         TA          Y         298            0              0           0
# 2         TA          Y           0           42              0           0
# 3         TA          Y           0           35            272           0
# 4         TA          Y         192           84              0           0
#
#    ScreenPorch  PoolArea PoolQC Fence MiscFeature  MiscVal  MoSold  YrSold  \
# 0            0         0    NaN   NaN         NaN        0       2    2008
# 1            0         0    NaN   NaN         NaN        0       5    2007
# 2            0         0    NaN   NaN         NaN        0       9    2008
# 3            0         0    NaN   NaN         NaN        0       2    2006
# 4            0         0    NaN   NaN         NaN        0      12    2008
#
#   SaleCondition  XFlrSF_total  SaleType_COD  SaleType_CWD  SaleType_Con  \
# 0        Normal          1710         False         False         False
# 1        Normal          1262         False         False         False
# 2        Normal          1786         False         False         False
# 3       Abnorml          1717         False         False         False
# 4        Normal          2198         False         False         False
#
#    SaleType_ConLD  SaleType_ConLI  SaleType_ConLw  SaleType_New  SaleType_Oth  \
# 0           False           False           False         False         False
# 1           False           False           False         False         False
# 2           False           False           False         False         False
# 3           False           False           False         False         False
# 4           False           False           False         False         False
#
#    SaleType_WD
# 0         True
# 1         True
# 2         True
# 3         True
# 4         True

# %% [markdown]
# ### フィルタリング
#
# DataFrameの `query()` を使いフィルタリングを行ないましょう。
#
# 参考：https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.query.html

# %%
# 'YearBuilt'が2000以降の物件のみを抽出し、最初の5件のみ表示
dataset.query("YearBuilt >= 2000").head()
# Out:
#     Order  area   price  MSSubClass MSZoning  LotFrontage  LotArea Street  \
# 0       1  1710  208500          60       RL         65.0     8450   Pave
# 2       3  1786  223500          60       RL         68.0    11250   Pave
# 4       5  2198  250000          60       RL         84.0    14260   Pave
# 6       7  1694  307000          20       RL         75.0    10084   Pave
# 11     12  2324  345000          60       RL         85.0    11924   Pave
#
#    Alley LotShape LandContour Utilities LotConfig LandSlope Neighborhood  \
# 0    NaN      Reg         Lvl    AllPub    Inside       Gtl      CollgCr
# 2    NaN      IR1         Lvl    AllPub    Inside       Gtl      CollgCr
# 4    NaN      IR1         Lvl    AllPub       FR2       Gtl      NoRidge
# 6    NaN      Reg         Lvl    AllPub    Inside       Gtl      Somerst
# 11   NaN      IR1         Lvl    AllPub    Inside       Gtl      NridgHt
#
#    Condition1 Condition2 BldgType HouseStyle  OverallQual  OverallCond  \
# 0        Norm       Norm     1Fam     2Story            7            5
# 2        Norm       Norm     1Fam     2Story            7            5
# 4        Norm       Norm     1Fam     2Story            8            5
# 6        Norm       Norm     1Fam     1Story            8            5
# 11       Norm       Norm     1Fam     2Story            9            5
#
#     YearBuilt  YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd  \
# 0        2003          2003     Gable  CompShg     VinylSd     VinylSd
# 2        2001          2002     Gable  CompShg     VinylSd     VinylSd
# 4        2000          2000     Gable  CompShg     VinylSd     VinylSd
# 6        2004          2005     Gable  CompShg     VinylSd     VinylSd
# 11       2005          2006       Hip  CompShg     WdShing     Wd Shng
#
#    MasVnrType  MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond  \
# 0     BrkFace       196.0        Gd        TA      PConc       Gd       TA
# 2     BrkFace       162.0        Gd        TA      PConc       Gd       TA
# 4     BrkFace       350.0        Gd        TA      PConc       Gd       TA
# 6       Stone       186.0        Gd        TA      PConc       Ex       TA
# 11      Stone       286.0        Ex        TA      PConc       Ex       TA
#
#    BsmtExposure BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  BsmtUnfSF  \
# 0            No          GLQ         706          Unf           0        150
# 2            Mn          GLQ         486          Unf           0        434
# 4            Av          GLQ         655          Unf           0        490
# 6            Av          GLQ        1369          Unf           0        317
# 11           No          GLQ         998          Unf           0        177
#
#     TotalBsmtSF Heating HeatingQC CentralAir Electrical  X1stFlrSF  X2ndFlrSF  \
# 0           856    GasA        Ex          Y      SBrkr        856        854
# 2           920    GasA        Ex          Y      SBrkr        920        866
# 4          1145    GasA        Ex          Y      SBrkr       1145       1053
# 6          1686    GasA        Ex          Y      SBrkr       1694          0
# 11         1175    GasA        Ex          Y      SBrkr       1182       1142
#
#     LowQualFinSF  BsmtFullBath  BsmtHalfBath  FullBath  HalfBath  \
# 0              0             1             0         2         1
# 2              0             1             0         2         1
# 4              0             1             0         2         1
# 6              0             1             0         2         0
# 11             0             1             0         3         0
#
#     BedroomAbvGr  KitchenAbvGr KitchenQual  TotRmsAbvGrd Functional  \
# 0              3             1          Gd             8        Typ
# 2              3             1          Gd             6        Typ
# 4              4             1          Gd             9        Typ
# 6              3             1          Gd             7        Typ
# 11             4             1          Ex            11        Typ
#
#     Fireplaces FireplaceQu GarageType  GarageYrBlt GarageFinish  GarageCars  \
# 0            0         NaN     Attchd       2003.0          RFn           2
# 2            1          TA     Attchd       2001.0          RFn           2
# 4            1          TA     Attchd       2000.0          RFn           3
# 6            1          Gd     Attchd       2004.0          RFn           2
# 11           2          Gd    BuiltIn       2005.0          Fin           3
#
#     GarageArea GarageQual GarageCond PavedDrive  WoodDeckSF  OpenPorchSF  \
# 0          548         TA         TA          Y           0           61
# 2          608         TA         TA          Y           0           42
# 4          836         TA         TA          Y         192           84
# 6          636         TA         TA          Y         255           57
# 11         736         TA         TA          Y         147           21
#
#     EnclosedPorch  X3SsnPorch  ScreenPorch  PoolArea PoolQC Fence MiscFeature  \
# 0               0           0            0         0    NaN   NaN         NaN
# 2               0           0            0         0    NaN   NaN         NaN
# 4               0           0            0         0    NaN   NaN         NaN
# 6               0           0            0         0    NaN   NaN         NaN
# 11              0           0            0         0    NaN   NaN         NaN
#
#     MiscVal  MoSold  YrSold SaleType SaleCondition  XFlrSF_total
# 0         0       2    2008       WD        Normal          1710
# 2         0       9    2008       WD        Normal          1786
# 4         0      12    2008       WD        Normal          2198
# 6         0       8    2007       WD        Normal          1694
# 11        0       7    2006      New       Partial          2324

# %% [markdown]
# `'LotArea >= 15000 and MSSubClass >= 50'` のように複数の条件を指定できます。

# %%
# 'YearBuilt'が2000以降、'GarageCars'が3以上の物件を抽出し、最初の5件のみ表示
dataset.query("YearBuilt >= 2000 and GarageCars >= 3").head()
# Out:
#     Order  area   price  MSSubClass MSZoning  LotFrontage  LotArea Street  \
# 4       5  2198  250000          60       RL         84.0    14260   Pave
# 11     12  2324  345000          60       RL         85.0    11924   Pave
# 13     14  1494  279500          20       RL         91.0    10652   Pave
# 20     21  2376  325300          60       RL        101.0    14215   Pave
# 25     26  1600  256300          20       RL        110.0    14230   Pave
#
#    Alley LotShape LandContour Utilities LotConfig LandSlope Neighborhood  \
# 4    NaN      IR1         Lvl    AllPub       FR2       Gtl      NoRidge
# 11   NaN      IR1         Lvl    AllPub    Inside       Gtl      NridgHt
# 13   NaN      IR1         Lvl    AllPub    Inside       Gtl      CollgCr
# 20   NaN      IR1         Lvl    AllPub    Corner       Gtl      NridgHt
# 25   NaN      Reg         Lvl    AllPub    Corner       Gtl      NridgHt
#
#    Condition1 Condition2 BldgType HouseStyle  OverallQual  OverallCond  \
# 4        Norm       Norm     1Fam     2Story            8            5
# 11       Norm       Norm     1Fam     2Story            9            5
# 13       Norm       Norm     1Fam     1Story            7            5
# 20       Norm       Norm     1Fam     2Story            8            5
# 25       Norm       Norm     1Fam     1Story            8            5
#
#     YearBuilt  YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd  \
# 4        2000          2000     Gable  CompShg     VinylSd     VinylSd
# 11       2005          2006       Hip  CompShg     WdShing     Wd Shng
# 13       2006          2007     Gable  CompShg     VinylSd     VinylSd
# 20       2005          2006     Gable  CompShg     VinylSd     VinylSd
# 25       2007          2007     Gable  CompShg     VinylSd     VinylSd
#
#    MasVnrType  MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond  \
# 4     BrkFace       350.0        Gd        TA      PConc       Gd       TA
# 11      Stone       286.0        Ex        TA      PConc       Ex       TA
# 13      Stone       306.0        Gd        TA      PConc       Gd       TA
# 20    BrkFace       380.0        Gd        TA      PConc       Ex       TA
# 25      Stone       640.0        Gd        TA      PConc       Gd       TA
#
#    BsmtExposure BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  BsmtUnfSF  \
# 4            Av          GLQ         655          Unf           0        490
# 11           No          GLQ         998          Unf           0        177
# 13           Av          Unf           0          Unf           0       1494
# 20           Av          Unf           0          Unf           0       1158
# 25           No          Unf           0          Unf           0       1566
#
#     TotalBsmtSF Heating HeatingQC CentralAir Electrical  X1stFlrSF  X2ndFlrSF  \
# 4          1145    GasA        Ex          Y      SBrkr       1145       1053
# 11         1175    GasA        Ex          Y      SBrkr       1182       1142
# 13         1494    GasA        Ex          Y      SBrkr       1494          0
# 20         1158    GasA        Ex          Y      SBrkr       1158       1218
# 25         1566    GasA        Ex          Y      SBrkr       1600          0
#
#     LowQualFinSF  BsmtFullBath  BsmtHalfBath  FullBath  HalfBath  \
# 4              0             1             0         2         1
# 11             0             1             0         3         0
# 13             0             0             0         2         0
# 20             0             0             0         3         1
# 25             0             0             0         2         0
#
#     BedroomAbvGr  KitchenAbvGr KitchenQual  TotRmsAbvGrd Functional  \
# 4              4             1          Gd             9        Typ
# 11             4             1          Ex            11        Typ
# 13             3             1          Gd             7        Typ
# 20             4             1          Gd             9        Typ
# 25             3             1          Gd             7        Typ
#
#     Fireplaces FireplaceQu GarageType  GarageYrBlt GarageFinish  GarageCars  \
# 4            1          TA     Attchd       2000.0          RFn           3
# 11           2          Gd    BuiltIn       2005.0          Fin           3
# 13           1          Gd     Attchd       2006.0          RFn           3
# 20           1          Gd    BuiltIn       2005.0          RFn           3
# 25           1          Gd     Attchd       2007.0          RFn           3
#
#     GarageArea GarageQual GarageCond PavedDrive  WoodDeckSF  OpenPorchSF  \
# 4          836         TA         TA          Y         192           84
# 11         736         TA         TA          Y         147           21
# 13         840         TA         TA          Y         160           33
# 20         853         TA         TA          Y         240          154
# 25         890         TA         TA          Y           0           56
#
#     EnclosedPorch  X3SsnPorch  ScreenPorch  PoolArea PoolQC Fence MiscFeature  \
# 4               0           0            0         0    NaN   NaN         NaN
# 11              0           0            0         0    NaN   NaN         NaN
# 13              0           0            0         0    NaN   NaN         NaN
# 20              0           0            0         0    NaN   NaN         NaN
# 25              0           0            0         0    NaN   NaN         NaN
#
#     MiscVal  MoSold  YrSold SaleType SaleCondition  XFlrSF_total
# 4         0      12    2008       WD        Normal          2198
# 11        0       7    2006      New       Partial          2324
# 13        0       8    2007      New       Partial          1494
# 20        0      11    2006      New       Partial          2376
# 25        0       7    2009       WD        Normal          1600

# %% [markdown]
# ## 5. データの可視化

# %% [markdown]
# データを理解するには要約統計量や抽出したデータを確認するだけでは不充分であり、可視化が必要です。

# %% [markdown]
# ### ヒストグラム
#
# 連続変数の分布を確認する際に有効です。DataFrameの `hist()` が使えます。
#
# 参考：https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.hist.html

# %%
# datasetの'price'をヒストグラムで表示（DataFrameのhist()を利用する）
dataset['price'].hist(bins=20)

# bins = ヒストグラムのデータを分割する区間の数。bins=20 → データを20個の区間に分割してヒストグラムを作成する
# Out:
# <Axes: >

# %% [markdown]
# ### 散布図
#
# 2つの変数の関係性を確認する際に有効です。DataFrameの `plot()` が使えます。
#
# 参考：https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.plot.html

# %%
# datasetの'LotArea'と'price'を散布図で表示（DataFrameのplot()を利用する）
dataset.plot(kind='scatter', x='LotArea', y='price')
# Out:
# <Axes: xlabel='LotArea', ylabel='price'>

# %% [markdown]
# ### 棒グラフ
#
# 大小や増減を比較する際に有効です。DataFrameの `plot.bar()` が使えます。
#
# 参考：https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.plot.bar.html

# %%
#'price'のSaleConditionごとの平均を変数 price_by_condition に格納
price_by_condition = dataset[['SaleCondition', 'price']].groupby('SaleCondition').mean().reset_index()

# %%
# price_by_conditionが持つ、棒グラフを表示する命令を実行
price_by_condition.plot.bar(x='SaleCondition')
# Out:
# <Axes: xlabel='SaleCondition'>

# %% [markdown]
# ### 箱ヒゲ図 (Boxplot)
#
# 複数の変数の分布を比較する際に有効です（棒グラフでは平均の比較はできますが、分布全体の比較はできません)。
#
# DataFrameの `boxplot()` が使えます。
#
# 参考：https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.boxplot.html

# %%
# datasetの'SaleCondition'ごとに'price'をDataFrameのboxplotで表示
ax = dataset.boxplot(column='price', by='SaleCondition')
ax.set_title('')
# Out:
# Text(0.5, 1.0, '')

# %% [markdown]
# ## 6. 欠損値の確認
#
# ある列が欠損値を持っているかどうかは Pandas の `isnull()` でわかります。特定の列の欠損値を知りたい場合は `pd.isnull(dataset['LotFrontage'])` のように記述します。また、`.sum()` をつなげることで、その列で欠損値を持つ行数がわかります。
#
# 参考：https://pandas.pydata.org/docs/reference/api/pandas.isnull.html

# %%
# すべての列がそれぞれ、欠損値が何行あるかを取得
dataset.isnull().sum()
# Out:
# Order            0
# area             0
# price            0
# MSSubClass       0
# MSZoning         0
#                 ..
# MoSold           0
# YrSold           0
# SaleType         0
# SaleCondition    0
# XFlrSF_total     0
# Length: 82, dtype: int64
